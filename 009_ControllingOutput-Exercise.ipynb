# %%
# install dependencies 
# %pip install anthropic python-dotenv

# %%
# Load env variables 
from dotenv import load_dotenv

load_dotenv()

# %%
#Create an API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
#MultiChat Helpers

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)
    
def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

prompt =""" Generate three different sample AWS CLI commands. Each shoud be very short ."""
add_user_message(messages, prompt)
add_assistant_message(messages, "Here are all three comands in a single block without any comments \n ```bash")

text = chat(messages, stop_sequences=["```"])
text.strip()

# %%
from IPython.display import Markdown

# Display the response as formatted Markdown which is especially useful if the response contains code snippets or lists, as it will render them in a more readable way.
Markdown(text)

# %% [markdown]
# ```bash
# aws s3 ls
# aws ec2 describe-instancess
# aws lambda list-functions
